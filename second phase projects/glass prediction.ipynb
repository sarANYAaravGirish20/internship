# %% [markdown]
#                          Glass Identification project

# %% [markdown]
# Problem Statement:
#     The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties.We have to predict the glass type by analysing all the chemical properties of the glass  like RI: refractive index Na: Sodium, Mg: Magnesium, Al:Aluminum,Si:Silicon,K: Potassium, Ca: Calcium Ba: Barium,Fe: Iron.we have 10 features and one target variable(Type)

# %%
#importing all  necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# load the  dataset
df=pd.read_csv("glass.csv",index_col=None)

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# There are 214 observations in the dataset. The dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).
# 	1- building_windows_float_processed
# 	2- building_windows_non_float_processed
# 	3- vehicle_windows_float_processed
# 	4- vehicle_windows_non_float_processed (none in this database)
# 	5- containers
# 	6- tableware
# 	7- headlamps

# %%
# to determine the shape of the dataset
df.shape
# Out:
# (214, 10)

# %%
#To find the columns
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
#Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
#count the glass types
df['Type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
#To check the null values 
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %% [markdown]
# There are  no null values present in the given dataset.

# %%
#Anaslysis using count plot
sns.countplot('Type',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %% [markdown]
# Type of glass: (class attribute) [1-7]
#
# 1) Building_windows_float_processed
# 2) Building_windows_non_float_processed
# 3) Vehicle_windows_float_processed
# 4) Vehicle_windows_non_float_processed
# 5) Containers
# 6) Tableware
# 7) Headlamps

# %%
#statistical summary of the dataset
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
#  Here,I observed that features are not in same scale.
# :silicon(si) mean value 72.65.its very high when compared to other features
# :Na(Sodium) having mean value 13.
# :minimum values are zero for some properties.
# :Maximum value is more for silicon

# %%
#lets analyse via distplot
sns.distplot(df['RI'])
# Out:
# <AxesSubplot:xlabel='RI', ylabel='Density'>

# %%
sns.distplot(df['Na'],bins=20)
# Out:
# <AxesSubplot:xlabel='Na', ylabel='Density'>

# %%
sns.distplot(df['Mg'],bins=20)
# Out:
# <AxesSubplot:xlabel='Mg', ylabel='Density'>

# %%
sns.distplot(df['Si'],bins=20)
# Out:
# <AxesSubplot:xlabel='Si', ylabel='Density'>

# %%
sns.distplot(df['K'],bins=20)
# Out:
# <AxesSubplot:xlabel='K', ylabel='Density'>

# %%
sns.distplot(df['Al'],bins=20)
# Out:
# <AxesSubplot:xlabel='Al', ylabel='Density'>

# %%
sns.distplot(df['Ba'],bins=20)
# Out:
# <AxesSubplot:xlabel='Ba', ylabel='Density'>

# %%
sns.distplot(df['Fe'],bins=20)
# Out:
# <AxesSubplot:xlabel='Fe', ylabel='Density'>

# %% [markdown]
# All features are not normally distributed and not balanced in the above distplot

# %%
#Lets analyse BOXPLOT
sns.boxplot(x='Type', y='RI', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='RI'>

# %%
sns.boxplot(x='Type', y='Na', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Na'>

# %%
sns.boxplot(x='Type', y='K', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='K'>

# %%
sns.boxplot(x='Type', y='Si', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Si'>

# %%
sns.boxplot(x='Type', y='Ca', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Ca'>

# %%
sns.boxplot(x='Type', y='Ba', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Ba'>

# %%
sns.boxplot(x='Type', y='Fe', data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Fe'>

# %% [markdown]
# From the corresponding Box plot, we have seen Fe(iron),Ba(Barium) have no pattern.
# Sodium content is higher in Type 6,7
# Magnesium content is fairly high in Type 1, 2 & 3.
# pottasium is higher only in type 5.
# Al higher in 5,7

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),cbar=True,fmt='.1f',cmap= 'coolwarm',annot=True)
plt.show()

# %% [markdown]
# Ca and Ri are strongly corelated according to the heatmap

# %%
X = df.drop(columns='Type',axis=1)
y = df['Type']

# %%
X
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Decision Tree
DeciTree = tree.DecisionTreeClassifier()
DeciTree.fit(X_train, y_train)
y_pred = DeciTree.predict(X_test)
acc = metrics.accuracy_score(y_pred,y_test)
print(acc)
# Out:
# 0.6296296296296297

# %%
# Random Forest
RandFore = RandomForestClassifier(max_depth = 3,random_state = 1)
RandFore.fit(X_train, y_train)
y_pred = RandFore.predict(X_test)
acc1 = metrics.accuracy_score(y_pred,y_test)
print(acc1)
# Out:
# 0.6111111111111112
