# %% [markdown]
# #                                    World Happiness report

# %% [markdown]
# Problem Statement:
# The World Happiness Report is a landmark survey of the state of global happiness.The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.The goal of the project is to predict the happiness score of the countries by analysing the features given in the data set.
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.

# %%
#import all necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# load happiness score dataset 
df=pd.read_csv("happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#to find the shape of the data set
df.shape
# Out:
# (158, 12)

# %% [markdown]
# There are 158 rows and 12 columns

# %%
#First 5 rows and columns
df.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#To find columns
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#To list the columns
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
#check null values present or not
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# check data types
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Rank',y='Health (Life Expectancy)',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Happiness Rank',data=df)
plt.show()

# %%
#To check null values 
df['Dystopia Residual'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Name: Dystopia Residual, Length: 158, dtype: bool

# %%
#To find the number of unique values
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Dystopia Residual',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Freedom',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Trust (Government Corruption)',data=df)
plt.show()

# %%
#plt.figure(figsize=(5)
sns.barplot(x='Happiness Score',y='Region',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Standard Error',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Generosity',data=df)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Happiness Score',y='Family',data=df)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',hue ='Region',data=df)
plt.show()

# %%
#Statistical summary of the dataset
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#count the features
df.count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
df.sort_values(by="Happiness Rank", ascending=True)
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.sort_values(by="Happiness Rank", ascending=False,)
# Out:
#          Country                           Region  Happiness Rank  \
# 157         Togo               Sub-Saharan Africa             158
# 156      Burundi               Sub-Saharan Africa             157
# 155        Syria  Middle East and Northern Africa             156
# 154        Benin               Sub-Saharan Africa             155
# 153       Rwanda               Sub-Saharan Africa             154
# ..           ...                              ...             ...
# 4         Canada                    North America               5
# 3         Norway                   Western Europe               4
# 2        Denmark                   Western Europe               3
# 1        Iceland                   Western Europe               2
# 0    Switzerland                   Western Europe               1
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 157            2.839         0.06727                   0.20868  0.13995
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title("Happiness score boxplot by region", fontsize = 20)
sns.boxplot(y="Region", x="Happiness Score", data=df)
plt.show()

# %%
a = df.sort_values(by='Happiness Score', ascending= False).head(10)
a
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Highest Happiness Rank belongs to Western Europe

# %%
b= df.sort_values(by='Happiness Score', ascending= True).head(10)
b
# Out:
#           Country                           Region  Happiness Rank  \
# 157          Togo               Sub-Saharan Africa             158
# 156       Burundi               Sub-Saharan Africa             157
# 155         Syria  Middle East and Northern Africa             156
# 154         Benin               Sub-Saharan Africa             155
# 153        Rwanda               Sub-Saharan Africa             154
# 152   Afghanistan                    Southern Asia             153
# 151  Burkina Faso               Sub-Saharan Africa             152
# 150   Ivory Coast               Sub-Saharan Africa             151
# 149        Guinea               Sub-Saharan Africa             150
# 148          Chad               Sub-Saharan Africa             149
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 157            2.839         0.06727                   0.20868  0.13995
# 156            2.905         0.08658                   0.01530  0.41587
# ...

# %% [markdown]
#  Lowest Happiness Ranks(10) belongs to sub saharan Africa and southern Asia

# %%
df1=df.groupby('Region')
df1['Happiness Score'].describe().sort_values(by='max', ascending=True).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
#
#                                    50%      75%    max
# Region
# Southern Asia                    4.565  4.94400  5.253
# ...

# %% [markdown]
# Here, western Europe has maximum Happiness Score(7.587)
# Southern Asia has minimum Happiness Score(4.2028).

# %%
corr_df=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_df,annot= True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df['Happiness Score'].max()
# Out:
# 7.587

# %%
df['Happiness Score'].min()
# Out:
# 2.839

# %%
df[['Country','Happiness Rank']].head(10)
# Out:
#        Country  Happiness Rank
# 0  Switzerland               1
# 1      Iceland               2
# 2      Denmark               3
# 3       Norway               4
# 4       Canada               5
# 5      Finland               6
# 6  Netherlands               7
# 7       Sweden               8
# 8  New Zealand               9
# 9    Australia              10

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
df.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
# categorical values are elimimnated from the dataset using slicing
df1 = df[df.columns[3:]]
df1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber =1
for column in df1:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df1[column], color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
#  Here Standard error,Trust are not normally distributed.some skewnes are there in the plot.For solving this we have to use cuberoot
#     method

# %%
#check skewness 
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Lets analyse via distplot

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber =1
for column in df1:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df1[column], color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Lets analyse via Boxplot

# %%
df.plot(kind ='box', subplots = True, layout=(3,4))
plt.tight_layout()

# %% [markdown]
# no more outliers are shown above in the plot.

# %%
#Separate variables
X=df1.drop(columns =['Happiness Score'])
Y=df1['Happiness Score']

# %%
Y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.182211        -0.201754
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.182211                 -0.785267
# Happiness Score                     -0.201754                  0.780966
# ...

# %%
corr_df=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_df,annot= True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, Y_train)
print(regr.score(X_test, Y_test))
# Out:
# 0.9999999060974577
